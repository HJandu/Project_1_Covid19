# %% [markdown]
# ## Suicide rates in areas within the London region

# %%
# Dependencies and Setup
import matplotlib as mpl
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
import seaborn as sns

# Study data files
during_covid_path = "CSVs/DuringCovid_a.csv"
pre_covid_path = "CSVs/PreCovid_a.csv"

# Read the covid data and the study results
during_covid = pd.read_csv(during_covid_path)
pre_covid = pd.read_csv(pre_covid_path)


# Display the data table for preview

# %%
during_covid
# Out:
#                 Parent Name             Area Name Time period      Value  \
# 0         North East region            Hartlepool   2019 - 21  14.667019
# 1         North East region         Middlesbrough   2019 - 21  14.879852
# 2         North East region  Redcar and Cleveland   2019 - 21  19.750601
# 3         North East region      Stockton-on-Tees   2019 - 21  10.206445
# 4         North East region            Darlington   2019 - 21  16.598023
# ..                      ...                   ...         ...        ...
# 147  East of England region               Suffolk   2019 - 21  10.387505
# 148       South East region                Surrey   2019 - 21  10.096817
# 149    West Midlands region          Warwickshire   2019 - 21  11.215052
# 150       South East region           West Sussex   2019 - 21  11.533312
# 151    West Midlands region        Worcestershire   2019 - 21  12.015792
#
#      Count Compared to England value or percentiles  \
# 0     36.0                                  Similar
# 1     54.0                                    Worse
# 2     69.0                                    Worse
# 3     52.0                                  Similar
# 4     47.0                                    Worse
# ..     ...                                      ...
# 147  208.0                                  Similar
# 148  316.0                                  Similar
# 149  172.0                                  Similar
# 150  265.0                                  Similar
# 151  186.0                                  Similar
#
#     Compared to Region value or percentiles
# 0                                   Similar
# 1                                   Similar
# 2                                     Worse
# 3                                   Similar
# 4                                   Similar
# ..                                      ...
# 147                                 Similar
# 148                                 Similar
# 149                                 Similar
# 150                                 Similar
# 151                                 Similar
#
# [152 rows x 7 columns]

# %%
pre_covid
# Out:
#                 Parent Name             Area Name Time period      Value  \
# 0         North East region            Hartlepool   2017 - 19  10.361530
# 1         North East region         Middlesbrough   2017 - 19  14.464680
# 2         North East region  Redcar and Cleveland   2017 - 19  13.538658
# 3         North East region      Stockton-on-Tees   2017 - 19   8.673680
# 4         North East region            Darlington   2017 - 19  13.646433
# ..                      ...                   ...         ...        ...
# 145  East of England region               Suffolk   2017 - 19   9.531723
# 146       South East region                Surrey   2017 - 19   8.180909
# 147    West Midlands region          Warwickshire   2017 - 19   9.382023
# 148       South East region           West Sussex   2017 - 19   9.678995
# 149    West Midlands region        Worcestershire   2017 - 19  10.479799
#
#      Count Compared to England value or percentiles  \
# 0     26.0                                  Similar
# 1     49.0                                    Worse
# 2     47.0                                  Similar
# 3     45.0                                  Similar
# 4     38.0                                  Similar
# ..     ...                                      ...
# 145  188.0                                  Similar
# 146  255.0                                   Better
# 147  143.0                                  Similar
# 148  216.0                                  Similar
# 149  164.0                                  Similar
#
#     Compared to Region value or percentiles
# 0                                   Similar
# 1                                   Similar
# 2                                   Similar
# 3                                    Better
# 4                                   Similar
# ..                                      ...
# 145                                 Similar
# 146                                  Better
# 147                                 Similar
# 148                                 Similar
# 149                                 Similar
#
# [150 rows x 7 columns]

# %%
#Dataframe for areas in the London region pre-covid
not_lr = []
for x in range(len(pre_covid)):
    if pre_covid["Parent Name"][x] != "London region":
        not_lr.append(x)
pre_covid.drop(not_lr, inplace=True)
pre_covid.reset_index(drop=True, inplace=True)
pre_covid
# Out:
#       Parent Name               Area Name Time period      Value  Count  \
# 0   London region          City of London   2017 - 19        NaN    4.0
# 1   London region    Barking and Dagenham   2017 - 19   6.066265   32.0
# 2   London region                  Barnet   2017 - 19   6.707621   66.0
# 3   London region                  Bexley   2017 - 19   8.924822   57.0
# 4   London region                   Brent   2017 - 19   7.070716   61.0
# 5   London region                 Bromley   2017 - 19   7.436294   64.0
# 6   London region                  Camden   2017 - 19  11.343694   69.0
# 7   London region                 Croydon   2017 - 19   9.535119   93.0
# 8   London region                  Ealing   2017 - 19   9.072835   78.0
# 9   London region                 Enfield   2017 - 19   5.887038   50.0
# 10  London region               Greenwich   2017 - 19   8.877856   59.0
# 11  London region                 Hackney   2017 - 19   8.229369   53.0
# 12  London region  Hammersmith and Fulham   2017 - 19  10.958199   50.0
# 13  London region                Haringey   2017 - 19   9.563817   65.0
# 14  London region                  Harrow   2017 - 19   4.932766   33.0
# 15  London region                Havering   2017 - 19   7.180964   47.0
# 16  London region              Hillingdon   2017 - 19   9.495983   74.0
# 17  London region                Hounslow   2017 - 19  10.564505   71.0
# 18  London region               Islington   2017 - 19  10.412614   54.0
# 19  London region  Kensington and Chelsea   2017 - 19   9.124496   38.0
# 20  London region    Kingston upon Thames   2017 - 19  10.341803   47.0
# 21  London region                 Lambeth   2017 - 19   8.140767   63.0
# 22  London region                Lewisham   2017 - 19   8.930034   68.0
# 23  London region                  Merton   2017 - 19   7.319035   38.0
# 24  London region                  Newham   2017 - 19   6.594160   56.0
# 25  London region               Redbridge   2017 - 19   7.139417   52.0
# 26  London region    Richmond upon Thames   2017 - 19   9.207278   46.0
# 27  London region               Southwark   2017 - 19   8.919773   70.0
# 28  London region                  Sutton   2017 - 19  10.368256   54.0
# 29  London region           Tower Hamlets   2017 - 19   8.703623   67.0
# 30  London region          Waltham Forest   2017 - 19   8.734307   59.0
# 31  London region              Wandsworth   2017 - 19   8.768473   66.0
# 32  London region             Westminster   2017 - 19   5.995366   41.0
#
#    Compared to England value or percentiles  \
# 0                              Not compared
# 1                                    Better
# 2                                    Better
# 3                                   Similar
# 4                                    Better
# 5                                    Better
# 6                                   Similar
# 7                                   Similar
# 8                                   Similar
# 9                                    Better
# 10                                  Similar
# 11                                  Similar
# 12                                  Similar
# 13                                  Similar
# 14                                   Better
# 15                                   Better
# 16                                  Similar
# 17                                  Similar
# 18                                  Similar
# 19                                  Similar
# 20                                  Similar
# 21                                  Similar
# 22                                  Similar
# 23                                  Similar
# 24                                   Better
# 25                                   Better
# 26                                  Similar
# 27                                  Similar
# 28                                  Similar
# 29                                  Similar
# 30                                  Similar
# 31                                  Similar
# 32                                   Better
#
#    Compared to Region value or percentiles
# 0                             Not compared
# 1                                  Similar
# 2                                  Similar
# 3                                  Similar
# 4                                  Similar
# 5                                  Similar
# 6                                    Worse
# 7                                  Similar
# 8                                  Similar
# 9                                   Better
# 10                                 Similar
# 11                                 Similar
# 12                                 Similar
# 13                                 Similar
# 14                                  Better
# 15                                 Similar
# 16                                 Similar
# 17                                 Similar
# 18                                 Similar
# 19                                 Similar
# 20                                 Similar
# 21                                 Similar
# 22                                 Similar
# 23                                 Similar
# 24                                 Similar
# 25                                 Similar
# 26                                 Similar
# 27                                 Similar
# 28                                 Similar
# 29                                 Similar
# 30                                 Similar
# 31                                 Similar
# 32                                 Similar

# %%
#Dataframe for areas in the London region during covid
not_lr_c = []
for x in range(len(during_covid)):
    if during_covid["Parent Name"][x] != "London region":
        not_lr_c.append(x)
during_covid.drop(not_lr_c, inplace=True)
during_covid.reset_index(drop=True, inplace=True)
during_covid
# Out:
#       Parent Name               Area Name Time period      Value  Count  \
# 0   London region          City of London   2019 - 21        NaN    3.0
# 1   London region    Barking and Dagenham   2019 - 21   8.816308   44.0
# 2   London region                  Barnet   2019 - 21   4.768270   50.0
# 3   London region                  Bexley   2019 - 21   7.225304   47.0
# 4   London region                   Brent   2019 - 21   5.264526   47.0
# 5   London region                 Bromley   2019 - 21   5.136692   43.0
# 6   London region                  Camden   2019 - 21   8.897871   55.0
# 7   London region                 Croydon   2019 - 21   6.216146   62.0
# 8   London region                  Ealing   2019 - 21   9.784855   83.0
# 9   London region                 Enfield   2019 - 21   5.308389   44.0
# 10  London region               Greenwich   2019 - 21   6.837920   47.0
# 11  London region                 Hackney   2019 - 21   8.597457   56.0
# 12  London region  Hammersmith and Fulham   2019 - 21  12.912275   70.0
# 13  London region                Haringey   2019 - 21   7.240601   50.0
# 14  London region                  Harrow   2019 - 21   5.374674   34.0
# 15  London region                Havering   2019 - 21   8.447265   57.0
# 16  London region              Hillingdon   2019 - 21   8.829208   70.0
# 17  London region                Hounslow   2019 - 21   8.842165   63.0
# 18  London region               Islington   2019 - 21   7.858980   41.0
# 19  London region  Kensington and Chelsea   2019 - 21  10.238240   43.0
# 20  London region    Kingston upon Thames   2019 - 21   7.898383   36.0
# 21  London region                 Lambeth   2019 - 21   5.660215   45.0
# 22  London region                Lewisham   2019 - 21   8.333238   62.0
# 23  London region                  Merton   2019 - 21   6.479712   37.0
# 24  London region                  Newham   2019 - 21   5.963181   54.0
# 25  London region               Redbridge   2019 - 21   7.680508   57.0
# 26  London region    Richmond upon Thames   2019 - 21   7.083961   37.0
# 27  London region               Southwark   2019 - 21   9.015502   70.0
# 28  London region                  Sutton   2019 - 21  10.603738   56.0
# 29  London region           Tower Hamlets   2019 - 21   6.625520   58.0
# 30  London region          Waltham Forest   2019 - 21   6.535544   47.0
# 31  London region              Wandsworth   2019 - 21   7.458149   60.0
# 32  London region             Westminster   2019 - 21   7.388662   51.0
#
#    Compared to England value or percentiles  \
# 0                              Not compared
# 1                                   Similar
# 2                                    Better
# 3                                    Better
# 4                                    Better
# 5                                    Better
# 6                                   Similar
# 7                                    Better
# 8                                   Similar
# 9                                    Better
# 10                                   Better
# 11                                  Similar
# 12                                  Similar
# 13                                   Better
# 14                                   Better
# 15                                  Similar
# 16                                  Similar
# 17                                  Similar
# 18                                  Similar
# 19                                  Similar
# 20                                  Similar
# 21                                   Better
# 22                                  Similar
# 23                                   Better
# 24                                   Better
# 25                                   Better
# 26                                   Better
# 27                                  Similar
# 28                                  Similar
# 29                                   Better
# 30                                   Better
# 31                                   Better
# 32                                   Better
#
#    Compared to Region value or percentiles
# 0                             Not compared
# 1                                  Similar
# 2                                   Better
# 3                                  Similar
# 4                                   Better
# 5                                   Better
# 6                                  Similar
# 7                                  Similar
# 8                                    Worse
# 9                                   Better
# 10                                 Similar
# 11                                 Similar
# 12                                   Worse
# 13                                 Similar
# 14                                 Similar
# 15                                 Similar
# 16                                 Similar
# 17                                 Similar
# 18                                 Similar
# 19                                   Worse
# 20                                 Similar
# 21                                 Similar
# 22                                 Similar
# 23                                 Similar
# 24                                 Similar
# 25                                 Similar
# 26                                 Similar
# 27                                 Similar
# 28                                   Worse
# 29                                 Similar
# 30                                 Similar
# 31                                 Similar
# 32                                 Similar

# %%
labels= ['Barking and Dagenham',  'Barnet', 'Bexley', 'Brent', 'Bromley', 'Camden', 'Croydon', 'Ealing', 'Enfield', 'Greenwich', 'Hackney', 'Hammersmith and Fulham', 'Haringey', 'Harrow', 'Havering', 'Hillingdon', 'Hounslow', 'Islington', 'Kensington and Chelsea', 'Kingston upon Thames', 'Lambeth', 'Lewisham', 'Merton', 'Newham', 'Redbridge', 'Richmond upon Thames', 'Southwark', 'Sutton', 'Tower Hamlets', 'Waltham Forest', 'Wandsworth', 'Westminster']

# %%
w=0.2
x = ['Barking and Dagenham', 'Barnet', 'Bexley', 'Brent', 'Bromley', 'Camden', 'Croydon', 'Ealing', 'Enfield', 'Greenwich', 'Hackney', 'Hammersmith and Fulham','Haringey', 'Harrow', 'Havering','Hillingdon','Hounslow', 'Islington', 'Kensington and Chelsea', 'Kingston upon Thames', 'Lambeth', 'Lewisham', 'Merton', 'Newham', 'Redbridge', 'Richmond upon Thames', 'Southwark', 'Sutton', 'Tower Hamlets', 'Waltham Forest', 'Wandsworth', 'Westminster']

pre_covid = [6.066265, 6.707621,  8.924822, 7.070716, 7.436294, 11.343694, 9.535119, 9.072835, 5.887038, 8.877856, 8.229369, 10.958199, 9.563817, 4.932766, 7.180964, 9.495983, 10.564505, 10.412614, 9.124496, 10.341803, 8.140767, 8.930034, 7.319035, 6.594160, 7.139417, 9.207278, 8.919773, 10.368256, 8.703623, 8.734307, 8.768473, 5.995366]
during_covid = [8.816308, 4.768270, 7.225304, 5.264526, 5.136692, 8.897871, 6.216146, 9.784855, 5.308389, 6.837920, 8.597457, 12.912275, 7.240601, 5.374674, 8.447265, 8.829208, 8.842165, 7.858980, 10.238240, 7.898383, 5.660215, 8.333238, 6.479712, 5.963181, 7.680508, 7.083961, 9.015502, 10.603738, 6.625520, 6.535544, 7.458149, 7.388662]


bar1 = np.arange(len(x))
bar2 = [i+w for i in bar1]

plt.bar(bar1, pre_covid,w,label="Pre Covid")
plt.bar(bar2, during_covid,w,label="During Covid")

plt.xlabel('Areas in the London region')
plt.ylabel('Suicide Rate (Per 100,00)')
plt.title('Suicide rate before and during Covid \nby areas in the London region')
plt.legend()
plt.xticks(bar1+w/2, x, rotation=80)
plt.rcParams["figure.figsize"] = (30,10)
plt.savefig('Images/suicide_by_area_London_region.png')
